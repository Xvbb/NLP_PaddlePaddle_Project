# %%
# !. train.sh
# Out:
# -----------  Configuration Arguments -----------
# backend: auto
# elastic_server: None
# force: False
# gpus: 0
# heter_devices:
# heter_worker_num: None
# heter_workers:
# host: None
# http_port: None
# ips: 127.0.0.1
# job_id: None
# log_dir: log
# np: None
# nproc_per_node: None
# run_mode: None
# scale: 0
# server_num: None
# servers:
# training_script: train.py
# training_script_args: ['--device', 'cpu', '--save_dir', './checkpoints/', '--batch_size', '64', '--learning_rate', '5E-5', '--epochs', '10', '--save_steps', '100', '--eval_steps', '1000', '--max_seq_length', '64', '--infer_with_fc_pooler', '--dropout', '0.1', '--train_set_file', '/home/aistudio/data/data52714/lcqmc/train.tsv', '--test_set_file', '/home/aistudio/data/data52714/lcqmc/dev.tsv']
# worker_num: None
# workers:
# ------------------------------------------------
# WARNING 2022-01-02 18:45:20,937 launch.py:423] Not found distinct arguments and compiled with cuda or xpu. Default use collective mode
# ...
